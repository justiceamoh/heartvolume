# %% [markdown]
# # A Deep Neural Network Regressor - Rework for TBME
#
# My first stab at this task will be to implement an **DNN Regressor** model.

# %%
# %matplotlib inline

#Basic Imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Sklearn Imports
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
# !ls data7

# %%
# df = pd.read_csv('data7/train.csv',header=None)
# print df.info()
# df.head()

# %%
# x_data = df.iloc[:,:-1].values.reshape((-1,30,224))
# y_data = df.iloc[:, -1].values

# %%
# Data load function
def load_data(filename,prints=False,spatial=False):
    data   = pd.read_csv(filename,header=None)
    if spatial:
        x_data = data.iloc[:,:-1].values.reshape((-1,30,224,1))
    else:
        x_data = data.iloc[:,:-1].values
    y_data = data.iloc[:,-1].values
    if prints:
        print 'X shape:', x_data.shape
        print 'Y shape:', y_data.shape
    return x_data,y_data

# %%
dataid   = 7
filename = 'data{}/train.csv'.format(dataid)
x_train,y_train=load_data(filename,spatial=True)
scaler   = MinMaxScaler(feature_range=(0,1)).fit(y_train.reshape(-1,1))
y_train  = scaler.transform(y_train.reshape(-1,1)).squeeze()
x_train,x_valid,y_train,y_valid = train_test_split(x_train,y_train,test_size=0.25,random_state=32)

# %% [markdown]
# ## Regressor Model

# %%
# Keras Imports
from keras.models import Model, load_model
from keras.layers import Input, Dense, Lambda, AveragePooling2D
from keras.layers import Flatten, Reshape, BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.advanced_activations import PReLU
from keras import regularizers
from keras import backend as K
from keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint
from keras.callbacks import TensorBoard
# Out:
# /home/junior/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
## Training Params
num_batch = 28
num_epoch = 30
patience  = 10

# Parameters
# ndim = x_train.shape[1]
npat,ndim,_ = x_train.shape[1:]
L1   = 127
L2   = 169
L3   = 16

# %%
# Build DNN
def build_model(cnn=False):
    if not cnn:
        x = Input(shape=(ndim,),name='Input')
        h = Dense(L1,activation='relu',name='L1')(x)
        h = BatchNormalization()(h)
        h = Dense(L2,activation='relu',kernel_regularizer=regularizers.l2(0.01),name='L2')(h)
        h = BatchNormalization()(h)
        h = Dense(L3,activation='relu',kernel_regularizer=regularizers.l2(0.01),name='L3')(h)
        h = BatchNormalization()(h)
        y = Dense(1,activation='linear',name='Output')(h)
        
    else:
        x = Input(shape=(npat,ndim,1),name='Input')
        h = Conv2D(28,kernel_size=(3,5),strides=(2,3),padding='same',name='L1')(x)
        h = BatchNormalization()(h)
        h = Conv2D(16,kernel_size=(3,3),strides=(2,3),padding='same',name='L2')(h)
        h = BatchNormalization()(h)
        h = Conv2D(15,kernel_size=(3,3),strides=(1,3),padding='same',name='L3')(h)
        h = BatchNormalization()(h)
        h = AveragePooling2D((2,2),strides=(2,2))(h)
        h = Flatten()(h)
        h = Dense(7,activation='relu',kernel_regularizer=regularizers.l2(0.01),name='L4')(h)
        y = Dense(1,activation='linear',name='Output')(h)

    model = Model(x,y)
    return model

# %%
x_train.shape
# Out:
# (43312, 30, 224, 1)

# %%
# Compile Model
model = build_model(cnn=True)
model.summary()
model.compile(optimizer='adam',loss='mean_squared_error')

modelname  = 'hypermodel.h5'
e_stopper  = EarlyStopping(monitor='val_loss', min_delta=0, patience=10)
checkpoint = ModelCheckpoint(modelname,monitor='val_loss',verbose=1,save_best_only=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           (None, 30, 224, 1)        0
# _________________________________________________________________
# L1 (Conv2D)                  (None, 15, 75, 28)        448
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 15, 75, 28)        112
# _________________________________________________________________
# L2 (Conv2D)                  (None, 8, 25, 16)         4048
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 25, 16)         64
# _________________________________________________________________
# L3 (Conv2D)                  (None, 8, 9, 15)          2175
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 8, 9, 15)          60
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 4, 4, 15)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 240)               0
# _________________________________________________________________
# L4 (Dense)                   (None, 7)                 1687
# _________________________________________________________________
# Output (Dense)               (None, 1)                 8
# =================================================================
# Total params: 8,602
# Trainable params: 8,484
# Non-trainable params: 118
# _________________________________________________________________

# %%
# Train Model
log = model.fit(x_train, y_train,
              batch_size=num_batch,
              epochs=num_epoch,
              shuffle=True,
              callbacks=[e_stopper,checkpoint],
              validation_data=(x_valid,y_valid))
# Out:
# Train on 43312 samples, validate on 14438 samples
# Epoch 1/30
# 43312/43312 [==============================] - 41s 955us/step - loss: 0.1267 - val_loss: 0.0524
#
# Epoch 00001: val_loss improved from inf to 0.05242, saving model to hypermodel.h5
# Epoch 2/30
# 43312/43312 [==============================] - 10s 220us/step - loss: 0.0352 - val_loss: 0.0313
#
# Epoch 00002: val_loss improved from 0.05242 to 0.03126, saving model to hypermodel.h5
# Epoch 3/30
# 43312/43312 [==============================] - 10s 231us/step - loss: 0.0267 - val_loss: 0.0229
#
# Epoch 00003: val_loss improved from 0.03126 to 0.02288, saving model to hypermodel.h5
# Epoch 4/30
# 43312/43312 [==============================] - 10s 229us/step - loss: 0.0235 - val_loss: 0.0208
#
# Epoch 00004: val_loss improved from 0.02288 to 0.02084, saving model to hypermodel.h5
# Epoch 5/30
# 43312/43312 [==============================] - 10s 237us/step - loss: 0.0218 - val_loss: 0.0220
#
# Epoch 00005: val_loss did not improve
# Epoch 6/30
# 43312/43312 [==============================] - 10s 220us/step - loss: 0.0201 - val_loss: 0.0185
#
# Epoch 00006: val_loss improved from 0.02084 to 0.01848, saving model to hypermodel.h5
# Epoch 7/30
# 43312/43312 [==============================] - 10s 224us/step - loss: 0.0189 - val_loss: 0.0178
#
# Epoch 00007: val_loss improved from 0.01848 to 0.01784, saving model to hypermodel.h5
# Epoch 8/30
# 43312/43312 [==============================] - 10s 221us/step - loss: 0.0174 - val_loss: 0.0178
#
# Epoch 00008: val_loss improved from 0.01784 to 0.01779, saving model to hypermodel.h5
# Epoch 9/30
# 43312/43312 [==============================] - 10s 221us/step - loss: 0.0170 - val_loss: 0.0147
#
# Epoch 00009: val_loss improved from 0.01779 to 0.01471, saving model to hypermodel.h5
# Epoch 10/30
# 43312/43312 [==============================] - 10s 226us/step - loss: 0.0162 - val_loss: 0.0147
#
# Epoch 00010: val_loss did not improve
# Epoch 11/30
# 43312/43312 [==============================] - 10s 227us/step - loss: 0.0158 - val_loss: 0.0175
#
# Epoch 00011: val_loss did not improve
# Epoch 12/30
# 43312/43312 [==============================] - 10s 222us/step - loss: 0.0152 - val_loss: 0.0156
#
# Epoch 00012: val_loss did not improve
# Epoch 13/30
# 43312/43312 [==============================] - 10s 227us/step - loss: 0.0147 - val_loss: 0.0153
#
# Epoch 00013: val_loss did not improve
# Epoch 14/30
# 43312/43312 [==============================] - 10s 229us/step - loss: 0.0146 - val_loss: 0.0115
#
# Epoch 00014: val_loss improved from 0.01471 to 0.01151, saving model to hypermodel.h5
# Epoch 15/30
# 43312/43312 [==============================] - 10s 221us/step - loss: 0.0142 - val_loss: 0.0124
#
# Epoch 00015: val_loss did not improve
# Epoch 16/30
# 43312/43312 [==============================] - 9s 219us/step - loss: 0.0142 - val_loss: 0.0131
#
# Epoch 00016: val_loss did not improve
# Epoch 17/30
# 43312/43312 [==============================] - 10s 226us/step - loss: 0.0135 - val_loss: 0.0148
#
# Epoch 00017: val_loss did not improve
# Epoch 18/30
# 43312/43312 [==============================] - 10s 222us/step - loss: 0.0135 - val_loss: 0.0123
#
# Epoch 00018: val_loss did not improve
# Epoch 19/30
# 43312/43312 [==============================] - 10s 224us/step - loss: 0.0133 - val_loss: 0.0160
#
# Epoch 00019: val_loss did not improve
# Epoch 20/30
# 43312/43312 [==============================] - 10s 224us/step - loss: 0.0132 - val_loss: 0.0106
#
# Epoch 00020: val_loss improved from 0.01151 to 0.01062, saving model to hypermodel.h5
# Epoch 21/30
# 43312/43312 [==============================] - 10s 223us/step - loss: 0.0128 - val_loss: 0.0117
#
# Epoch 00021: val_loss did not improve
# Epoch 22/30
# 43312/43312 [==============================] - 10s 220us/step - loss: 0.0123 - val_loss: 0.0138
#
# Epoch 00022: val_loss did not improve
# Epoch 23/30
# 43312/43312 [==============================] - 10s 222us/step - loss: 0.0126 - val_loss: 0.0138
#
# Epoch 00023: val_loss did not improve
# Epoch 24/30
# 43312/43312 [==============================] - 10s 220us/step - loss: 0.0120 - val_loss: 0.0138
#
# Epoch 00024: val_loss did not improve
# Epoch 25/30
# 43312/43312 [==============================] - 10s 221us/step - loss: 0.0121 - val_loss: 0.0097
#
# Epoch 00025: val_loss improved from 0.01062 to 0.00966, saving model to hypermodel.h5
# Epoch 26/30
# 43312/43312 [==============================] - 10s 221us/step - loss: 0.0120 - val_loss: 0.0130
#
# Epoch 00026: val_loss did not improve
# Epoch 27/30
# 43312/43312 [==============================] - 9s 216us/step - loss: 0.0118 - val_loss: 0.0109
#
# Epoch 00027: val_loss did not improve
# Epoch 28/30
# 43312/43312 [==============================] - 9s 218us/step - loss: 0.0115 - val_loss: 0.0096
#
# Epoch 00028: val_loss improved from 0.00966 to 0.00963, saving model to hypermodel.h5
# Epoch 29/30
# 43312/43312 [==============================] - 9s 218us/step - loss: 0.0115 - val_loss: 0.0111
#
# Epoch 00029: val_loss did not improve
# Epoch 30/30
# 43312/43312 [==============================] - 9s 217us/step - loss: 0.0114 - val_loss: 0.0094
#
# Epoch 00030: val_loss improved from 0.00963 to 0.00939, saving model to hypermodel.h5

# %%
# model.save('model{}.h5'.format(dataid))
model = load_model(modelname)

# %%
# Training Curves
plt.figure(figsize=(5,4))
plt.plot(log.epoch,log.history['loss'])
plt.plot(log.epoch,log.history['val_loss'],'g')
plt.title('Training Curves')
# plt.ylim([0,0.05])
plt.xlabel('Epochs')
plt.xlabel('MSE Loss')
plt.legend(['Train','Valid'])

# %%
# Generate Predictions for Test Set
plt.figure(figsize=(10,6))

fname = 'data{}/test.csv'.format(dataid)
x_test,y_test=load_data(fname,spatial=True)
y_test = scaler.transform(y_test.reshape(-1,1)).squeeze()
y_predict = model.predict(x_test)
loss = model.evaluate(x_test,y_test,verbose=0)


# y_tst = scaler.inverse_transform(y_test.squeeze())
# y_prd = scaler.inverse_transform(y_predict.squeeze())
plt.subplot(111)
plt.plot(y_test,'o-',alpha=0.5)
plt.plot(y_predict,'go-')
header = '{0}, mse={1:.02f}'.format(fname[9:-4],loss)
plt.title(header)

# oname = 'data{}/ypred.csv'.format(dataid)
# tname = 'data{}/ytest.csv'.format(dataid)
# np.savetxt(oname,y_predict,delimiter=',')
# np.savetxt(tname,y_test,delimiter=',')

plt.legend(['Original','Predicted'],loc=1)
plt.tight_layout()

# %% [markdown]
# ----
